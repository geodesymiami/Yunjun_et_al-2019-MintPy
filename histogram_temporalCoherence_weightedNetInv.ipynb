# %%
import os
import matplotlib.pyplot as plt
from pysar.utils import readfile
from pysar.simulation.plot import *


work_dir = '/Users/yunjunz/insarlab/PYSAR_EXAMPLE/AlcedoSenDT128/PYSAR/WEIGHT_NET_INV'
os.chdir(work_dir)
print('Go to directory: '+work_dir)


tcoh_noW, atr = readfile.read('temporalCoherence_noWeight.h5')
tcoh_fimW = readfile.read('temporalCoherence_fimWeight.h5')[0]
mask = readfile.read('waterMask.h5', datasetName='mask')[0]
# Out:
# Go to directory: /Users/yunjunz/insarlab/PYSAR_EXAMPLE/AlcedoSenDT128/PYSAR/WEIGHT_NET_INV

# %%
plt.figure(figsize=[10, 6])
#plt.hist(tcoh_noW[mask].flatten(), bins=200, histtype='step', log=True)
#plt.hist(tcoh_fimW[mask].flatten(), bins=200, histtype='step', log=True, alpha=0.5)
#plt.savefig('hist_tempCoh_weightNetInv.jpg', dpi=fig_dpi, bbox_right=True)
plt.show()
